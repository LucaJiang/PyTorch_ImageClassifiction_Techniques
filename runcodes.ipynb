# %% [markdown]
# First, you should allow colab to use GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change with your own path. It takes mintues to install dependency packages.

# %%
# %cd /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques
# %ls -a
# Out:
# /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques
# checkpoints/
# data/
# datamodules.py
# gan/
# .git/
# .gitignore
# GraphAttenViTBlocks.py
# img/
# LICENSE
# logs/
# .lr_find_55c5f721-3705-438f-9e0d-aa90f59eeb8d.ckpt
# .lr_find_64c1d250-e3c8-4dcc-a2a2-c4e4ce994c78.ckpt
# .lr_find_86a76fe5-43bf-4819-a2de-fa26933bba69.ckpt
# .lr_find_87655b48-cffb-43e5-acaa-f32c280bd5f0.ckpt
# .lr_find_8a34dfb5-55c6-405c-837c-ad6d679e0f35.ckpt
# .lr_find_f11f1684-8aad-4f1f-8c8f-1a9e2bd38e4f.ckpt
# __pycache__/
# README.md
# runcodes.ipynb
# saved_models/
# train.py
# wandb/

# %%
! pip install --quiet "lightning" "setuptools==67.4.0" "pytorch-lightning" "torchmetrics" "jedi>=0.16" "pytorch-lightning-bolts" "wandb" "finetuning-scheduler"

# %%
# !wandb offline
# !python train.py
# Out:
# wandb: Tracking run with wandb version 0.15.2
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Finding best initial lr: 100% 50/50 [00:06<00:00,  8.18it/s]`Trainer.fit` stopped: `max_steps=50` reached.
# Finding best initial lr: 100% 50/50 [00:06<00:00,  7.74it/s]
# Learning rate set to 0.017378008287493765
# Restoring states from the checkpoint path at /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/checkpoints/.lr_find_6cb22220-5653-4782-8401-c0aaa01fde36.ckpt
# Restored all states from the checkpoint at /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/checkpoints/.lr_find_6cb22220-5653-4782-8401-c0aaa01fde36.ckpt
# Files already downloaded and verified
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | ResNet | 21.3 M
# ---------------------------------
# 21.3 M    Trainable params
# 0         Non-trainable params
# 21.3 M    Total params
# 85.128    Total estimated model params size (MB)
# Epoch 4: 100% 704/704 [01:14<00:00,  9.40it/s, v_num=nj8b]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 10/79 [00:00<00:05, 13.48it/s]
# Validation DataLoader 0:  25% 20/79 [00:01<00:04, 13.57it/s]
# Validation DataLoader 0:  38% 30/79 [00:02<00:03, 14.42it/s]
# Validation DataLoader 0:  51% 40/79 [00:02<00:02, 14.86it/s]
# Validation DataLoader 0:  63% 50/79 [00:03<00:01, 15.19it/s]
# Validation DataLoader 0:  76% 60/79 [00:03<00:01, 15.44it/s]
# Validation DataLoader 0:  89% 70/79 [00:04<00:00, 15.64it/s]
# Epoch 4: 100% 704/704 [01:19<00:00,  8.81it/s, v_num=nj8b]
#                                                             Metric val_loss improved. New best score: 0.585
# Epoch 9: 100% 704/704 [01:31<00:00,  7.73it/s, v_num=nj8b]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 10/79 [00:00<00:03, 17.66it/s]
# Validation DataLoader 0:  25% 20/79 [00:01<00:03, 16.21it/s]
# Validation DataLoader 0:  38% 30/79 [00:01<00:03, 15.26it/s]
# Validation DataLoader 0:  51% 40/79 [00:02<00:02, 14.83it/s]
# Validation DataLoader 0:  63% 50/79 [00:03<00:01, 14.60it/s]
# Validation DataLoader 0:  76% 60/79 [00:04<00:01, 14.43it/s]
# Validation DataLoader 0:  89% 70/79 [00:04<00:00, 14.13it/s]
# Epoch 9: 100% 704/704 [01:36<00:00,  7.28it/s, v_num=nj8b]
#                                                             Metric val_loss improved by 0.289 >= min_delta = 0.0. New best score: 0.296
# Epoch 14: 100% 704/704 [01:30<00:00,  7.75it/s, v_num=nj8b]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 10/79 [00:00<00:03, 17.77it/s]
# Validation DataLoader 0:  25% 20/79 [00:01<00:03, 17.31it/s]
# Validation DataLoader 0:  38% 30/79 [00:01<00:02, 17.24it/s]
# Validation DataLoader 0:  51% 40/79 [00:02<00:02, 16.54it/s]
# Validation DataLoader 0:  63% 50/79 [00:03<00:01, 15.96it/s]
# Validation DataLoader 0:  76% 60/79 [00:03<00:01, 15.51it/s]
# Validation DataLoader 0:  89% 70/79 [00:04<00:00, 15.16it/s]
# Epoch 14: 100% 704/704 [01:36<00:00,  7.33it/s, v_num=nj8b]
# Epoch 19: 100% 704/704 [01:31<00:00,  7.73it/s, v_num=nj8b]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 10/79 [00:00<00:03, 18.14it/s]
# Validation DataLoader 0:  25% 20/79 [00:01<00:03, 17.44it/s]
# Validation DataLoader 0:  38% 30/79 [00:01<00:02, 17.42it/s]
# Validation DataLoader 0:  51% 40/79 [00:02<00:02, 17.43it/s]
# Validation DataLoader 0:  63% 50/79 [00:02<00:01, 17.29it/s]
# Validation DataLoader 0:  76% 60/79 [00:03<00:01, 17.16it/s]
# Validation DataLoader 0:  89% 70/79 [00:04<00:00, 17.13it/s]
# Epoch 19: 100% 704/704 [01:35<00:00,  7.36it/s, v_num=nj8b]
# Epoch 24: 100% 704/704 [01:30<00:00,  7.78it/s, v_num=nj8b]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/79 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 10/79 [00:00<00:04, 14.48it/s]
# Validation DataLoader 0:  25% 20/79 [00:01<00:04, 13.58it/s]
# Validation DataLoader 0:  38% 30/79 [00:02<00:03, 13.22it/s]
# Validation DataLoader 0:  51% 40/79 [00:03<00:02, 13.07it/s]
# Validation DataLoader 0:  63% 50/79 [00:03<00:02, 13.34it/s]
# Validation DataLoader 0:  76% 60/79 [00:04<00:01, 13.86it/s]
# Validation DataLoader 0:  89% 70/79 [00:04<00:00, 14.27it/s]
# Epoch 24: 100% 704/704 [01:35<00:00,  7.34it/s, v_num=nj8b]
#                                                             Monitored metric val_loss did not improve in the last 3 records. Best score: 0.296. Signaling Trainer to stop.
# Epoch 24: 100% 704/704 [01:35<00:00,  7.34it/s, v_num=nj8b]
# Files already downloaded and verified
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 157/157 [00:07<00:00, 21.70it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_acc          │    0.7818999886512756     │
# │         test_loss         │    0.6511009931564331     │
# └───────────────────────────┴───────────────────────────┘
# wandb: WARNING Saving files without folders. If you want to preserve sub directories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/train.py", line 273, in <module>
#     # Save the best checkpoint
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py", line 345, in wrapper_fn
#     return func(self, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py", line 335, in wrapper
#     return func(self, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py", line 1783, in save
#     return self._save(glob_str, base_path, policy)
#   File "/usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py", line 1837, in _save
#     os.symlink(abs_path, wandb_path)
# OSError: [Errno 95] Operation not supported: '/content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/checkpoints/CIFAR10/yqnenj8b/checkpoints/epoch=9-step=2464.ckpt' -> '/content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/wandb/offline-run-20230512_150008-yqnenj8b/files/epoch=9-step=2464.ckpt'
# wandb: Waiting for W&B process to finish... (failed 1).
# wandb:
# wandb: Run history:
# wandb:               epoch ▁▃▄▆██
# wandb:              lr-SGD ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇▇██
# wandb:            test_acc ▁
# wandb:           test_loss ▁
# wandb:          train_loss █▆▅▄▄▅▂▃▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▂▂▂▂▂▂▂▂▃▂▂▃▂▃▂▃
# wandb: trainer/global_step ▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇██
# wandb:             val_acc ▄█▇▁▃
# wandb:            val_loss ▅▁▂█▆
# wandb:
# wandb: Run summary:
# wandb:               epoch 25
# wandb:              lr-SGD 0.08805
# wandb:            test_acc 0.7819
# wandb:           test_loss 0.6511
# wandb:          train_loss 0.8706
# wandb: trainer/global_step 13024
# wandb:             val_acc 0.7698
# wandb:            val_loss 0.70855
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/wandb/offline-run-20230512_150008-yqnenj8b
# wandb: Find logs at: ./wandb/offline-run-20230512_150008-yqnenj8b/logs
