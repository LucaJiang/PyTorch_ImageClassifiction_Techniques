# %% [markdown]
# First, you should allow colab to use GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change with your own path. It takes mintues to install dependency packages.

# %%
# %cd /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques
# %ls -a
# Out:
# /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques
# checkpoints/    .git/                   predict.py        saved_models/
# data/           .gitignore              __pycache__/      slideshow/
# datamodules.py  GraphAttenViTBlocks.py  README.md         train.py
# doc/            img/                    requirements.txt  wandb/
# gan/            LICENSE                 runcodes.ipynb

# %%
! pip install --quiet "lightning" "setuptools==67.4.0" "pytorch-lightning" "torchmetrics" "jedi>=0.16" "pytorch-lightning-bolts" "wandb" "finetuning-scheduler"

# %%
# !wandb online
# !wandb offline
# !python train.py
# Out:
# wandb: Currently logged in as: jiangwx7 (hkust-ddm). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.2
# wandb: Run data is saved locally in /content/drive/MyDrive/5055/PyTorch_ImageClassifiction_Techniques/wandb/run-20230515_025710-ucwtrrz6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run neat-snowball-12
# wandb: ⭐️ View project at https://wandb.ai/hkust-ddm/CIFAR10
# wandb: 🚀 View run at https://wandb.ai/hkust-ddm/CIFAR10/runs/ucwtrrz6
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | ResNet | 21.3 M
# ...

# %%
! python predict.py
